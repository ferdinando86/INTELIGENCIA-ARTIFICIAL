# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn import metrics
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.linear_model import Perceptron
from sklearn.neural_network import MLPClassifier
import matplotlib.pyplot as plt
import pandas as pd

wine = pd.read_csv("winequality-red.csv")
wine.head()

data = wine.values[:,:11]
data_columns = list(wine.columns.values[:11])
target=wine.values[:,11]

X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.3,random_state=109)

# %% [markdown]
# ## Perceptron
#
# Clasificar los datos correspondientes al dataset de vino tinto utilizando un perceptron

# %%
p = Perceptron(
             # random_state=42,
              max_iter=150,
              tol=0.001              
              )
p.fit(X_train, y_train)
print("Cantidad de iteraciones: " +str(p.n_iter_))
disp = metrics.plot_confusion_matrix(p, X_test, y_test,cmap=plt.cm.Blues)
disp.ax_.set_title('Confusion Matrix')
plt.show()
# Out:
# Cantidad de iteraciones: 10

# %% [markdown]
# - ¿Es posible clasificar correctamente los casos utilizando un Perceptron?
# - ¿Cuántas iteraciones son necesarias?

# %% [markdown]
# Si es posible, pero no es el metodo optimo, clasifica mal

# %% [markdown]
# ## Perceptron multicapa
#
# Clasificar los datos correspondientes al dataset de vino tinto utilizando un perceptron multicapa

# %%
activation = "identity"
#activation = "logistic"
#activation = "tanh"
#activation = "relu"
mlp = MLPClassifier(#random_state=42,
                    hidden_layer_sizes=(10,2),
                    max_iter = 1000,
                    activation = activation,
                    verbose = True
                    )
mlp.fit(X_train, y_train)
# Out:
# Iteration 1, loss = inf
# Iteration 2, loss = inf
# Iteration 3, loss = inf
# Iteration 4, loss = inf
# Iteration 5, loss = inf
# Iteration 6, loss = inf
# Iteration 7, loss = inf
# Iteration 8, loss = inf
# Iteration 9, loss = inf
# Iteration 10, loss = inf
# Iteration 11, loss = inf
# Iteration 12, loss = inf
# Iteration 13, loss = 31.16470475
# Iteration 14, loss = 29.43997370
# Iteration 15, loss = 27.81428617
# Iteration 16, loss = 26.27796799
# Iteration 17, loss = 24.95740689
# Iteration 18, loss = 23.63118717
# Iteration 19, loss = 22.39395986
# Iteration 20, loss = 21.23493593
# Iteration 21, loss = 20.10052706
# Iteration 22, loss = 18.94871929
# Iteration 23, loss = 17.86197306
# Iteration 24, loss = 16.83908573
# Iteration 25, loss = 15.85842487
# Iteration 26, loss = 14.82549364
# Iteration 27, loss = 13.86026124
# Iteration 28, loss = 12.88892389
# Iteration 29, loss = 11.96778465
# Iteration 30, loss = 11.07467606
# Iteration 31, loss = 10.20130476
# Iteration 32, loss = 9.29782657
# Iteration 33, loss = 8.42703758
# Iteration 34, loss = 7.64723353
# Iteration 35, loss = 7.07262776
# Iteration 36, loss = 6.83043519
# Iteration 37, loss = 6.43636665
# Iteration 38, loss = 6.11243526
# Iteration 39, loss = 5.85754190
# Iteration 40, loss = 5.59703858
# Iteration 41, loss = 5.34252500
# Iteration 42, loss = 5.13283549
# Iteration 43, loss = 4.96570399
# Iteration 44, loss = 4.79599470
# Iteration 45, loss = 4.62788401
# Iteration 46, loss = 4.47871890
# Iteration 47, loss = 4.33493969
# Iteration 211, loss = 1.13164703
# Iteration 212, loss = 1.13151968
# Iteration 213, loss = 1.13063075
# Iteration 214, loss = 1.13132356
# Iteration 215, loss = 1.12972124
# Iteration 216, loss = 1.13330555
# Iteration 217, loss = 1.13931491
# Iteration 218, loss = 1.13320246
# Iteration 219, loss = 1.13073584
# Iteration 220, loss = 1.13112521
# Iteration 221, loss = 1.12895086
# Iteration 222, loss = 1.13161296
# Iteration 223, loss = 1.13685966
# Iteration 224, loss = 1.13479209
# Iteration 225, loss = 1.12952290
# Iteration 226, loss = 1.12738617
# Iteration 227, loss = 1.12692164
# Iteration 228, loss = 1.12617245
# Iteration 229, loss = 1.12425738
# Iteration 230, loss = 1.12471827
# Iteration 231, loss = 1.11893638
# Iteration 232, loss = 1.12223447
# Iteration 233, loss = 1.12709004
# Iteration 234, loss = 1.12541010
# Iteration 235, loss = 1.12152237
# Iteration 236, loss = 1.12030181
# Iteration 237, loss = 1.11837111
# Iteration 238, loss = 1.12725510
# Iteration 239, loss = 1.13438928
# Iteration 240, loss = 1.13302208
# Iteration 241, loss = 1.12085468
# Iteration 242, loss = 1.12674760
# Iteration 243, loss = 1.13477853
# Iteration 244, loss = 1.12227733
# Iteration 245, loss = 1.11962565
# Iteration 246, loss = 1.11841846
# Iteration 247, loss = 1.11672330
# Iteration 248, loss = 1.11312605
# Iteration 249, loss = 1.11152285
# Iteration 250, loss = 1.11336711
# Iteration 251, loss = 1.11503300
# Iteration 252, loss = 1.11137678
# Iteration 253, loss = 1.11972972
# Iteration 254, loss = 1.10931955
# Iteration 255, loss = 1.11377283
# Iteration 256, loss = 1.11121817
# Iteration 257, loss = 1.11549478
# Iteration 258, loss = 1.12598544
# Iteration 259, loss = 1.11929660
# Iteration 260, loss = 1.12678190
# Iteration 261, loss = 1.13144176
# Iteration 262, loss = 1.11871654
# Iteration 263, loss = 1.12802290
# Iteration 264, loss = 1.12208378
# Iteration 265, loss = 1.12287039
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(activation='identity', alpha=0.0001, batch_size='auto',
#               beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(10, 2), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=1000,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=True,
#               warm_start=False)

# %%
print("Cantidad de iteraciones: " +str(mlp.n_iter_))
disp = metrics.plot_confusion_matrix(mlp, X_test, y_test,cmap=plt.cm.Blues)
disp.ax_.set_title('Confusion Matrix')
plt.show()
# Out:
# Cantidad de iteraciones: 265

# %% [markdown]
# - ¿Es posible clasificar correctamente los casos utilizando un Perceptron?
# - ¿Cuántas iteraciones son necesarias?

# %% [markdown]
# Si es posible clasificar, es mas optimo que el metodo simple capa.
# Cantidad de iteraciones: 192
#
# Si es posible clasificar utilizando este metodo, no es optimo al 100% pero es mejor al anterior,
# se utilizo un sistema de capas de 10,2 y con 188 iteraciones logro su mejor performance o version.
